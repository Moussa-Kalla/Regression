# %%
from drawdata import ScatterWidget
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import random

# %%
widget = ScatterWidget()
widget
# Out:
# ScatterWidget()

# %%
widget.data_as_pandas
widget.data_as_pandas.to_csv(r'C:\Python\Regression\Data\df.csv', index=False)

# %%
df = pd.read_csv(r'C:\Python\Regression\Data\df.csv')

# %%
df
# Out:
#               x           y    color label
# 0     33.822220   91.489811  #1f77b4     a
# 1     28.177057   90.746624  #1f77b4     a
# 2     29.785883   91.919224  #1f77b4     a
# 3     29.090446   88.073838  #1f77b4     a
# 4     39.053744   94.438212  #1f77b4     a
# ..          ...         ...      ...   ...
# 137  800.347909  225.853782  #1f77b4     a
# 138  811.181618  223.466525  #1f77b4     a
# 139  822.945231  226.122261  #1f77b4     a
# 140  825.012322  224.460668  #1f77b4     a
# 141  820.636042  225.705181  #1f77b4     a
#
# [142 rows x 4 columns]

# %%
plt.plot(df['x'], df['y'], 'o')

# %%
# Transformer les listes en numpy arrays et redimensionner x
x = df['x'].values.reshape(-1,1)
y = df['y'].values.reshape(-1,1)

# Choisissez le degré du polynôme (par exemple 2)
degree = 7

# Transformer les données en fonctionnalités polynomiales
poly_features = PolynomialFeatures(degree=degree)
x_poly = poly_features.fit_transform(x)

# Ajuster le modèle de régression linéaire
model = LinearRegression()
model.fit(x_poly, y)

# Prédictions (peut être utilisé pour tracer la courbe de régression)
y_pred = model.predict(x_poly)

plt.figure(figsize=(12, 7))
plt.plot(y_pred,color='r',label='Régression polynomiale de degré ' + str(degree))
plt.scatter(x,y, label='Données réelles')
plt.grid(True)
#plt.plot(xii, f(xii),color='g')
plt.title('Régression Polynomiale')
plt.xlabel('Variable indépendante x')
plt.ylabel('Variable dépendante y')
plt.grid(True)
plt.legend()
plt.show()

mse = np.mean((y - y_pred) ** 2)  
mse
# Out:
# 1488.751331722807
