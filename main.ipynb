# %%
from drawdata import ScatterWidget
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import random

# %%
widget = ScatterWidget()
widget
# Out:
# ScatterWidget()

# %%
widget.data_as_pandas
widget.data_as_pandas.to_csv(r'C:\Python\Regression\Data\df.csv', index=False)
df = pd.read_csv(r'C:\Python\Regression\Data\df.csv')
plt.plot(df['x'], df['y'], 'o')
df
# Out:
#               x           y    color label
# 0     47.574796   77.458893  #1f77b4     a
# 1     45.250742   92.153826  #1f77b4     a
# 2     54.760876   95.445775  #1f77b4     a
# 3     47.860673   97.495843  #1f77b4     a
# 4     30.290054  104.715956  #1f77b4     a
# ..          ...         ...      ...   ...
# 151  767.968802  425.276371  #1f77b4     a
# 152  763.791603  450.416455  #1f77b4     a
# 153  790.773448  434.476096  #1f77b4     a
# 154  780.285329  432.958818  #1f77b4     a
# 155  783.304025  443.914725  #1f77b4     a
#
# [156 rows x 4 columns]

# %%
x = df['x'].values.reshape(-1, 1)  
y = df['y'].values


degree = 3


poly_features = PolynomialFeatures(degree=degree)
x_poly = poly_features.fit_transform(x)


model = LinearRegression()
model.fit(x_poly, y)


y_pred = model.predict(x_poly)



plt.figure(figsize=(12, 7))
plt.scatter(x, y, label='Real Data', color='blue')
plt.plot(x, y_pred, color='red', label='Polynomial regression  degree' + str(degree))
plt.grid(True)
plt.title('Polynomial regression')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Calcul de l'erreur quadratique moyenne
mse = np.mean((y - y_pred) ** 2)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 189.3511329672107
